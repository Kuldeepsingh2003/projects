# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/content/bank-additional.csv',sep = ';')
df2=pd.read_csv('/content/bank-dataset-use-for-marketing.csv',sep = ';')

# %%
df1.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df2.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df1.shape
# Out:
# (4119, 21)

# %%
df2.shape
# Out:
# (41188, 21)

# %%
df1.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df2.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df1.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.duplicated().sum()
# Out:
# 12

# %%
df2.drop_duplicates(inplace=True)

# %%
df1['housing'].value_counts()
# Out:
# housing
# yes        2175
# no         1839
# unknown     105
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df1.sort_values('duration',ascending=False)
# Out:
#       age            job   marital            education default housing loan  \
# 2231   31     technician   married  professional.course      no      no   no
# 1546   46         admin.  divorced          high.school      no     yes   no
# 1392   47         admin.  divorced    university.degree      no     yes   no
# 1685   33    blue-collar    single          high.school      no      no   no
# 3266   49    blue-collar   married             basic.6y      no     yes   no
# ...   ...            ...       ...                  ...     ...     ...  ...
# 1896   30  self-employed    single             basic.9y      no      no  yes
# 2534   57         admin.  divorced    university.degree      no      no   no
# 2202   29     technician   married    university.degree      no      no   no
# 1600   28  self-employed    single             basic.9y      no     yes   no
# 1950   39         admin.   married          high.school      no     yes   no
#
# ...

# %% [markdown]
# #What is the share of clients attracted in our source data?

# %%
yes_share=df2['y'].str.contains('yes').mean()
print(f"share clients attracted:{yes_share:.2%}")
# Out:
# share clients attracted:11.27%

# %%
yes_share=df1['y'].str.contains('yes').mean()
print(f"share clients attracted:{yes_share:.2%}")
# Out:
# share clients attracted:10.95%

# %% [markdown]
# #What is the age distribution of clients in the dataset? Are there any noticeable patterns or outliers?

# %%
df2.age.max()
# Out:
# 98

# %%
df2.age.min()
# Out:
# 17

# %%
from sys import platlibdir
df2['age'].hist(bins=50)
plt.xlabel('age')
plt.ylabel('count')
plt.title('age distribution')
plt.show()

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Plot the age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df1['age'], bins=30, kde=True)
plt.title('Age Distribution of Clients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ###Most of the Clients in age betwwen in 30 to 40 year range and least client s are in 80 to  90
# ### younyest clients are 18 year old
# ### oldest client are 88 year old

# %% [markdown]
# #Job Analysis: Which job types are most common among clients? How does job type relate to the likelihood of subscribing to a term deposit?

# %%
df2.job.value_counts()
# Out:
# job
# admin.           10419
# blue-collar       9253
# technician        6739
# services          3967
# management        2924
# retired           1718
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
df1.job.value_counts().plot(kind='bar')
plt.xlabel('job')
plt.ylabel('count')
plt.title('job distribution')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='job', data=df1, order=df1['job'].value_counts().index)
plt.title('Job Type Distribution')
plt.xlabel('Count')
plt.ylabel('Job')
plt.show()

# Subscription rates by job type
job_subscription = df1.groupby('job')['y'].value_counts(normalize=True).unstack()
plt.figure(figsize=(12, 6))
job_subscription.plot(kind='bar', stacked=True)
plt.title('Subscription Rates by Job Type')
plt.xlabel('Job')
plt.ylabel('Proportion')
plt.show()

# %%
sns.catplot(x='job',hue='y',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('job')
plt.ylabel('count')
plt.title('job distribution')
plt.show()

# %% [markdown]
# #Marital Status: How does marital status affect the likelihood of subscribing to a term deposit? Are there significant differences in subscription rates between different marital statuses?

# %%
df1.marital.value_counts()
# Out:
# marital
# married     2509
# single      1153
# divorced     446
# unknown       11
# Name: count, dtype: int64

# %%
df1 = df1[df1['marital'] != 'unknown']
sns.catplot(x='marital',hue='y',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('matial status')
plt.ylabel('count')
plt.title('job distribution')
plt.show()

# %%
df1 = df1[df1['marital'] != 'unknown']
df1.dropna(subset=['marital'])
plt.figure(figsize=(8, 6))
sns.countplot(x='marital', data=df1, order=df1['marital'].value_counts().index)
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# Subscription rates by marital status
marital_subscription = df1.groupby('marital')['y'].value_counts(normalize=True).unstack()
plt.figure(figsize=(8, 6))
marital_subscription.plot(kind='bar', stacked=True)
plt.title('Subscription Rates by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# #What is the distribution of education levels among the clients? How does education level impact the success of the marketing campaign?

# %%
df1.education.value_counts()
# Out:
# education
# university.degree      1264
# high.school             921
# basic.9y                574
# professional.course     535
# basic.4y                429
# basic.6y                228
# unknown                 167
# illiterate                1
# Name: count, dtype: int64

# %%
df1.campaign.value_counts()
# Out:
# campaign
# 1     1764
# 2     1039
# 3      549
# 4      291
# 5      142
# 6       99
# 7       60
# 8       36
# 9       32
# 10      20
# 11      19
# 12      16
# 17      14
# 13      11
# 16       7
# 14       6
# 15       2
# 22       2
# 19       2
# 23       2
# 29       2
# 27       1
# 18       1
# 24       1
# 35       1
# Name: count, dtype: int64

# %% [markdown]
# ## Client education status

# %%
df1 = df1[df1['education'] != 'unknown']
sns.catplot(x='education',hue='education',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('education')
plt.ylabel('count')
plt.title('education distribution')
plt.show()

# %%
sns.catplot(x='education',hue='campaign',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('education')
plt.ylabel('count')
plt.title('education distribution')
plt.show()

# %%
df1[(df1['campaign']==6) & (df1['y'].str.contains('yes'))]
# Out:
#       age            job  marital    education default housing loan   contact  \
# 238    41       services  married  high.school      no      no   no  cellular
# 3593   39       services   single  high.school      no     yes   no  cellular
# 3879   50  self-employed  married     basic.9y      no     yes  yes  cellular
# 3980   43    blue-collar  married     basic.6y      no     yes   no  cellular
#
#      month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 238    mar         wed  ...         6    999         0  nonexistent
# 3593   aug         fri  ...         6    999         0  nonexistent
# 3879   may         mon  ...         6      3         1      success
# 3980   jun         mon  ...         6    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 238          -1.8          92.843          -50.0      1.778       5099.1  yes
# 3593         -1.7          94.027          -38.3      0.898       4991.6  yes
# ...

# %% [markdown]
# #Default, Housing, and Loan Status: How do credit default, housing loan, and personal loan statuses correlate with the likelihood of subscribing to a term deposit?

# %%
df1[(df1['housing']=='no') & (df1['loan'].str.contains('yes'))]
# Out:
#       age          job   marital          education  default housing loan  \
# 19     50  blue-collar   married           basic.4y       no      no  yes
# 23     40   management   married        high.school       no      no  yes
# 49     32     services   married        high.school       no      no  yes
# 67     29     services  divorced        high.school       no      no  yes
# 100    37   management   married  university.degree  unknown      no  yes
# ...   ...          ...       ...                ...      ...     ...  ...
# 4051   52     services   married        high.school       no      no  yes
# 4059   36     services   married        high.school       no      no  yes
# 4095   36       admin.    single  university.degree       no      no  yes
# 4102   31  blue-collar    single           basic.9y  unknown      no  yes
# 4111   30   technician   married  university.degree       no      no  yes
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
df1_sample=df1[['y','loan','housing']]

# %%
df1_sample.head()
# Out:
#     y     loan  housing
# 0  no       no      yes
# 1  no       no       no
# 2  no       no      yes
# 3  no  unknown  unknown
# 4  no       no      yes

# %% [markdown]
# ##personal loan and housing loan status

# %%
df1_sample = df1[['y', 'loan', 'housing']]
df1_sample = df1_sample[df1_sample['housing'] != 'unknown']


df1_sample(['loan', 'housing']).size().unstack().plot(kind='bar')
plt.xlabel('Loan and Housing Status')
plt.ylabel('Count')
plt.title('Loan and Housing Status for Clients Who Subscribed to Term Deposit')
plt.show()

# %%
df1_sample['loan_housing'] = df1_sample['loan'] + ', ' + df1_sample['housing']
df1_sample['loan_housing'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Loan and Housing Status for Clients Who Subscribed to Term Deposit')
plt.show()

# %%
sns.countplot(x='loan_housing', data=df1_sample,hue=df1_sample['y'])
plt.xlabel('Loan and Housing Status')
plt.ylabel('Count')
plt.title('Loan and Housing Status for Clients Who Subscribed to Term Deposit')
plt.show()

# %%
df1 = df1[df1['default'] != 'unknown']
sns.catplot(x='default',hue='y',data=df1,kind='count')
plt.xlabel('default credit score')
plt.ylabel('count')
plt.title('default distribution')
plt.show()

# %% [markdown]
# #Campaign Effectiveness: How does the number of contacts performed during this campaign (campaign) and the previous campaign (previous) influence the likelihood of a term deposit subscription?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['campaign'], bins=30, kde=True)
plt.xlabel('campaign')
plt.ylabel('count')
plt.title('campaign distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['previous'],kde=True)
plt.xlabel('previous')
plt.ylabel('count')
plt.title('previous distribution')
plt.show()

# %%
# prompt: graph for client contact form pdays after campagin from df1

import matplotlib.pyplot as plt
sns.catplot(x='pdays',hue='y',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('pdays')
plt.ylabel('count')
plt.title('pdays distribution')
plt.show()

# %%
sns.countplot(x='pdays', data=df1, )
plt.title('')
plt.xlabel('Client contact status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##(numeric; 999 means the client has not been previously contacted)

# %% [markdown]
# #Temporal Analysis: How do the month and day of the week of the last contact affect the likelihood of a successful subscription? Are there any trends or seasonal patterns?

# %%
sns.catplot(x='month',hue='y',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('month')
plt.ylabel('count')
plt.title('month distribution')
plt.show()

# %%
sns.catplot(x='day_of_week',hue='y',data=df1,kind='count')

# %% [markdown]
# ##Economic Indicators: How do economic indicators like emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, and nr.employed correlate with the success of the marketing campaign?

# %%
sns.catplot(x='emp.var.rate',hue='y',data=df1,kind='count')
plt.xlabel('emp.var.rate')
plt.ylabel('count')
plt.title('emp.var.rate distribution')
plt.show()

# %%
df1['emp.var.rate'].value_counts()
# Out:
# emp.var.rate
#  1.4    1626
# -1.8     883
#  1.1     758
# -0.1     392
# -2.9     164
# -3.4     104
# -1.7      87
# -1.1      83
# -3.0      21
# -0.2       1
# Name: count, dtype: int64

# %%
sns.catplot(x='cons.price.idx',hue='y',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('cons.price.idx')
plt.ylabel('count')
plt.title('cons.price.idx distribution')
plt.show()

# %% [markdown]
# ##Duration of Contact: How does the duration of the last contact relate to the likelihood of a term deposit subscription? Is there an optimal contact duration for success?

# %%
sns.catplot(x='duration',hue='y',data=df1,kind='bar')
plt.xticks(rotation=90)
plt.xlabel('duration')
plt.ylabel('count')
plt.title('duration distribution')
plt.show()

# %%
sns.catplot(x='poutcome',hue='y',data=df1,kind='count')

# %%
sns.catplot(x='cons.conf.idx',data=df1,kind='count')
plt.xticks(rotation=90)
plt.xlabel('cons.conf.idx')
plt.ylabel('count')
plt.title('cons.conf.idx distribution')
plt.show()

# %%
sns.catplot(x='cons.price.idx',data=df1,kind='boxen',hue='cons.price.idx')
plt.xticks(rotation=90)
plt.xlabel('cons.price.idx')
plt.ylabel('count')
plt.title('cons.price.idx distribution')
plt.show()

# %%
df1['duration']
# Out:
# 0       487
# 1       346
# 2       227
# 3        17
# 4        58
#        ...
# 4114     53
# 4115    219
# 4116     64
# 4117    528
# 4118    175
# Name: duration, Length: 4119, dtype: int64

# %%
df1['duration_minutes'] = df1['duration'] / 60
df1['duration_minutes']
# Out:
# 0       8.116667
# 1       5.766667
# 2       3.783333
# 3       0.283333
# 4       0.966667
#           ...
# 4114    0.883333
# 4115    3.650000
# 4116    1.066667
# 4117    8.800000
# 4118    2.916667
# Name: duration_minutes, Length: 4119, dtype: float64

# %%
df1['duration_hours'] = df1['duration_minutes'] / 60
df1['duration']
# Out:
# 0       487
# 1       346
# 2       227
# 3        17
# 4        58
#        ...
# 4114     53
# 4115    219
# 4116     64
# 4117    528
# 4118    175
# Name: duration, Length: 4119, dtype: int64

# %% [markdown]
# ## personal and housing loans distibution by months

# %%
loan_data = df1[df1['loan'] == 'yes']
loan_durations = loan_data['month']


plt.figure(figsize=(10, 6))
plt.hist(loan_durations, bins=30, edgecolor='black')
plt.xlabel('Loan Duration')
plt.ylabel('Frequency')
plt.title('Distribution of Loan by months')
plt.show()

# %%
loan_data = df1[df1['housing'] == 'yes']
loan_durations = loan_data['month']

plt.figure(figsize=(10, 6))
plt.hist(loan_durations, bins=30, edgecolor='black')
plt.xlabel('Loan ')
plt.ylabel('Frequency')
plt.title('Distribution of Loan  by months')
plt.show()

# %%
euribor3m_by_month = df1.groupby('month')['euribor3m'].mean()

plt.figure(figsize=(10, 6))
euribor3m_by_month.plot(kind='bar',edgecolor='black')
plt.xlabel('Month')
plt.ylabel('Euribor3m')
plt.title('Average the Euro Interbank Offered Rate  by 3 Month')
plt.show()

# %%
df1['euribor3m']
# Out:
# 0       1.313
# 1       4.855
# 2       4.962
# 3       4.959
# 4       4.191
#         ...
# 4114    4.958
# 4115    4.959
# 4116    1.354
# 4117    4.966
# 4118    4.120
# Name: euribor3m, Length: 3187, dtype: float64

# %%
sns.countplot(x=df1['nr.employed'], data=df1, )
plt.xticks(rotation=45)
plt.title('')
plt.xlabel('')
plt.ylabel('Count')
plt.show()

# %%
nr_employed_by_month = df1.groupby('month')['nr.employed'].mean()

nr_employed_by_month.plot(kind='bar', edgecolor='black')
plt.xlabel('Month')
plt.ylabel('Average Number of Employed')
plt.title('Average Number of Employed by Month')
plt.show()
