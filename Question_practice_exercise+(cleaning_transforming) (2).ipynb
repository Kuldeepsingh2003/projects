# %% [markdown]
# # Practice Exercise: Cleaning data & Transforming columns/features

# %% [markdown]
# ## Context:
# - The data is based on real anonymized Czech bank transactions and account info.
# - We'll be focusing on practicing the data cleaning, columns transformations, and other techniques that we've learned in the course.
# - But here is the original task description of the dataset publishers:
#
# *The bank wants to improve their services. For instance, the bank managers have only vague idea, who is a good client (whom to offer some additional services)   and who is a bad client (whom to watch carefully to minimize the bank losses). Fortunately, the bank stores data about their clients, the accounts (transactions within several months), the loans already granted, the credit cards issued. The bank managers hope to improve their understanding of customers and seek specific actions to improve services.*
#
# - We've made minor changes on the data to fit this exercise, such as changing the column names. Check out the original source if you are interested in using this data for other purposes (https://data.world/lpetrocelli/czech-financial-dataset-real-anonymized-transactions)

# %% [markdown]
# ## Dataset Description:
#
# We'll work on three datasets (in three separate csv files):
#
#   - **account**: each record describes static characteristics of an account
#   - **transaction**: each record describes one transaction on an account
#   - **district**: each record describes demographic characteristics of a district
#
# In reality, the organizations like banks often have data stored in multiple datasets. Assume we want to study the transactional level data, we'll need to combine these three datasets together to have transactions data with account and district data.

# %% [markdown]
# ## Objective:
#    - Examine/clean the individual dataset
#    - Combine them into a single dataset, which is subject to more cleaning
#    - Create new columns based on existing columns
#
# By the end, the new dataset is ready for more analysis.

# %% [markdown]
# ### 1. Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Import the data from three csv files as DataFrames `account`, `district`, `trans`
# Hint:
# - the `read_csv` function can automatically infer and load zip file, read its documentation of parameter `compression` if you are interested in details
# - you may ignore the warning when reading the `trans.csv.zip` file. It is optional to follow the warning instructions to remove it.

# %%
account=pd.read_csv('account.csv')
district=pd.read_csv('district.csv')
trans=pd.read_csv('trans.csv')

# %% [markdown]
# ### 3. Look at the info summary, head of each DataFrame

# %%
account.info()
print("")
district.info()
print("")
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   account_id         4500 non-null   int64
#  1   district_id        4500 non-null   int64
#  2   frequency          4500 non-null   object
#  3   account_open_date  4500 non-null   object
#  4   client_id          4500 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 175.9+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   district_id           76 non-null     int64
#  1   district_name         76 non-null     object
#  2   region                76 non-null     object
#  3   population            76 non-null     int64
#  4   average_salary        66 non-null     float64
#  5   unemployment_rate     66 non-null     float64
#  6   num_committed_crimes  67 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 4.3+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   trans_id         1056320 non-null  int64
#  1   account_id       1056320 non-null  int64
#  2   date             1056320 non-null  object
#  3   type             1056320 non-null  object
#  4   operation_type   873206 non-null   object
#  5   amount           1056320 non-null  float64
#  6   balance          1056320 non-null  float64
#  7   description      574439 non-null   object
#  8   partner_bank     273508 non-null   object
#  9   partner_account  295389 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 80.6+ MB

# %% [markdown]
# ### 4. Check for the unique values and their counts in each column for the three DataFrames

# %%
account.nunique()
# Out:
# account_id           4500
# district_id            77
# frequency               3
# account_open_date    1535
# client_id            4500
# dtype: int64

# %%
district.nunique()
# Out:
# district_id             76
# district_name           76
# region                   8
# population              76
# average_salary          65
# unemployment_rate       63
# num_committed_crimes    66
# dtype: int64

# %%
trans.nunique()
# Out:
# trans_id           1056320
# account_id            4500
# date                  2191
# type                     2
# operation_type           5
# amount               40400
# balance             542739
# description              8
# partner_bank            13
# partner_account       7665
# dtype: int64

# %% [markdown]
# ### 5. Check for duplicates in the three DataFrames

# %%
account.duplicated().sum()
# Out:
# 0

# %%
district.duplicated().sum()
# Out:
# 0

# %%
trans.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 6. Convert column `account_open_date` in `account` and column `date` in `trans` into datetime dtypes

# %%
account['account_open_date']=pd.to_datetime(account['account_open_date'])
trans['date']=pd.to_datetime(trans['date'])

# %% [markdown]
# ### 7. Convert the columns `region` and `district_name` in `district` to all uppercase

# %%
district['region']=district['region'].str.upper()
district['district_name']=district['district_name'].str.upper()

# %% [markdown]
# ### 8. Check for missing data by columns in `account` using the `isna` method

# %%
account.isna().sum()
# Out:
# account_id           0
# district_id          0
# frequency            0
# account_open_date    0
# client_id            0
# dtype: int64

# %% [markdown]
# ### 9. Check for missing data by columns in `district` using the `isna` method

# %%
district.isna().sum()
# Out:
# district_id              0
# district_name            0
# region                   0
# population               0
# average_salary          10
# unemployment_rate       10
# num_committed_crimes     9
# dtype: int64

# %% [markdown]
# `district` has numeric features that could have relationships with each other. Let's use iterative imputation on them.

# %% [markdown]
# #### Use `IterativeImputer` in `sklearn` to impute based on columns `population`, `average_salary`, `unemployment_rate`, `num_committed_crimes`

# %% [markdown]
# ##### Import libraries

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ##### Build a list of columns that will be used for imputation, which are `population`, `average_salary`, `unemployment_rate`, `num_committed_crimes`
# These are the columns that might be related to each other

# %%
cols_to_impute=['population','average_salary','unemployment_rate','num_committed_crimes']

# %% [markdown]
# ##### Create `IterativeImputer` object and set its `min_value` and `max_value` parameters to be the minumum and maximum of corresponding columns

# %%
imputer=IterativeImputer(min_value=district[cols_to_impute].min(),max_value=district[cols_to_impute].max())

# %% [markdown]
# ##### Apply the imputer to fit and transform the columns to an imputed NumPy array

# %%
imputed_cols = imputer.fit_transform(district[cols_to_impute])

# %% [markdown]
# ##### Assign the imputed array back to the original DataFrame's columns

# %%
district[cols_to_impute]=imputed_cols

# %% [markdown]
# ##### Double check that the columns are imputed

# %%
district.isna().sum()
# Out:
# district_id             0
# district_name           0
# region                  0
# population              0
# average_salary          0
# unemployment_rate       0
# num_committed_crimes    0
# dtype: int64

# %% [markdown]
# ### 10. Check for missing data by columns in `trans` using the `isna` method

# %%
trans.isna().sum()
# Out:
# trans_id                0
# account_id              0
# date                    0
# type                    0
# operation_type     183114
# amount                  0
# balance                 0
# description        481881
# partner_bank       782812
# partner_account    760931
# dtype: int64

# %% [markdown]
# #### Divide the columns into numeric columns and categorical columns, then use the `fillna` method to fill numeric columns with -999, fill categorical columns with 'UNKNOWN'

# %%
numeric_cols=trans.select_dtypes(include=np.number).columns
categorical_cols=trans.select_dtypes(exclude=np.number).columns

# %%
trans[numeric_cols]=trans[numeric_cols].fillna(-999)
trans[categorical_cols]=trans[categorical_cols].fillna('unknown')

# %% [markdown]
# ### 11. Check for outliers in `district` using the `describe` method, then look at the histograms of the suspicious columns

# %%
district.describe()
# Out:
#        district_id    population  average_salary  unemployment_rate  \
# count    76.000000  7.600000e+01       76.000000          76.000000
# mean     38.500000  1.336920e+05     8983.707247           3.864003
# std      22.083176  1.378127e+05      740.959314           1.721597
# min       1.000000  4.282100e+04     8110.000000           0.430000
# 25%      19.750000  8.472500e+04     8533.750000           2.650000
# 50%      38.500000  1.083910e+05     8792.984750           3.761936
# 75%      57.250000  1.382770e+05     9280.750000           4.570000
# max      76.000000  1.204953e+06    12541.000000           9.400000
#
#        num_committed_crimes
# count             76.000000
# mean            5054.492038
# std            11392.279917
# min              888.000000
# 25%             1918.454646
# 50%             2864.000000
# 75%             4562.413240
# max            99107.000000

# %%
district[['population','average_salary','num_committed_crimes','unemployment_rate']].hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'average_salary'}>],
#        [<Axes: title={'center': 'num_committed_crimes'}>,
#         <Axes: title={'center': 'unemployment_rate'}>]], dtype=object)

# %% [markdown]
# #### Explore the outliers in the dataset

# %%
district.nlargest(1,'population')
# Out:
#    district_id district_name  region  population  average_salary  \
# 0            1   HL.M. PRAHA  PRAGUE   1204953.0         12541.0
#
#    unemployment_rate  num_committed_crimes
# 0               0.43               99107.0

# %% [markdown]
# ### 12. Check for outliers in `trans` using the `describe` method, then look at the histograms of the suspicious columns

# %%
trans.describe()
# Out:
#            trans_id    account_id                           date  \
# count  1.056320e+06  1.056320e+06                        1056320
# mean   1.335311e+06  2.936867e+03  1997-01-04 07:29:27.037261952
# min    1.000000e+00  1.000000e+00            1993-01-01 00:00:00
# 25%    4.302628e+05  1.204000e+03            1996-01-16 00:00:00
# 50%    8.585065e+05  2.434000e+03            1997-04-10 00:00:00
# 75%    2.060979e+06  3.660000e+03            1998-02-28 00:00:00
# max    3.682987e+06  1.138200e+04            1998-12-31 00:00:00
# std    1.227487e+06  2.477345e+03                            NaN
#
#              amount       balance  partner_account
# count  1.056320e+06  1.056320e+06     1.056320e+06
# mean   5.924146e+03  3.851833e+04     1.277068e+07
# min    0.000000e+00 -4.112570e+04    -9.990000e+02
# 25%    1.359000e+02  2.240250e+04    -9.990000e+02
# 50%    2.100000e+03  3.314340e+04    -9.990000e+02
# 75%    6.800000e+03  4.960362e+04     3.410566e+06
# max    8.740000e+04  2.096370e+05     9.999420e+07
# std    9.522735e+03  2.211787e+04     2.613658e+07

# %%
trans[['amount','balance']].hist(figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'amount'}>,
#         <Axes: title={'center': 'balance'}>]], dtype=object)

# %% [markdown]
# #### Explore the outliers in the dataset

# %%
trans[trans['amount']>60000]
# Out:
#          trans_id  account_id       date    type  \
# 422       1313408        4484 1993-02-23   DEBIT
# 1287      1450519        4937 1993-04-04   DEBIT
# 3565       303136        1032 1993-06-05  CREDIT
# 3635       655858        2242 1993-06-06  CREDIT
# 3783       894506        3050 1993-06-08  CREDIT
# ...           ...         ...        ...     ...
# 1049226    602639        2051 1998-12-21   DEBIT
# 1049504    302367        1029 1998-12-22   DEBIT
# 1049791    335369        1139 1998-12-23   DEBIT
# 1050834    414144        1407 1998-12-26   DEBIT
# 1051694    378184        1286 1998-12-30   DEBIT
#
#                        operation_type   amount   balance description  \
# 422                WITHDRAWAL IN CASH  62100.0   41183.0     unknown
# 1287               WITHDRAWAL IN CASH  60500.0   74071.2     unknown
# 3565     COLLECTION FROM ANOTHER BANK  74648.0  112843.8     unknown
# 3635     COLLECTION FROM ANOTHER BANK  65240.0  126832.2     unknown
# 3783     COLLECTION FROM ANOTHER BANK  62168.0   73568.0     unknown
# ...                               ...      ...       ...         ...
# 1049226            WITHDRAWAL IN CASH  62000.0   71187.7     unknown
# 1049504            WITHDRAWAL IN CASH  63800.0   57501.1     unknown
# 1049791            WITHDRAWAL IN CASH  62600.0   90537.9     unknown
# 1050834            WITHDRAWAL IN CASH  62700.0   73836.1     unknown
# 1051694            WITHDRAWAL IN CASH  63400.0   55245.6     unknown
#
#         partner_bank  partner_account
# 422          unknown           -999.0
# 1287         unknown           -999.0
# 3565              GH       43027007.0
# 3635              CD        7862908.0
# 3783              GH       69871258.0
# ...              ...              ...
# 1049226      unknown           -999.0
# 1049504      unknown           -999.0
# 1049791      unknown           -999.0
# 1050834      unknown           -999.0
# 1051694      unknown           -999.0
#
# [1575 rows x 10 columns]

# %% [markdown]
# The DataFrame `account` doesn't have any columns that could have outliers, so we are not exploring it.

# %%
trans.loc[trans['amount']>60000,'operation_type'].value_counts()
# Out:
# operation_type
# WITHDRAWAL IN CASH              837
# COLLECTION FROM ANOTHER BANK    738
# Name: count, dtype: int64

# %% [markdown]
# ### 13. Merge (left join) `account` and `district` into a new DataFrame called `account_district` using their common columns

# %%
account_district=pd.merge(account,district,on='district_id',how='left')

# %% [markdown]
# ### 14. Check the information summary of `account_district`, any missing data?

# %%
account_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   account_id            4500 non-null   int64
#  1   district_id           4500 non-null   int64
#  2   frequency             4500 non-null   object
#  3   account_open_date     4500 non-null   datetime64[ns]
#  4   client_id             4500 non-null   int64
#  5   district_name         4460 non-null   object
#  6   region                4460 non-null   object
#  7   population            4460 non-null   float64
#  8   average_salary        4460 non-null   float64
#  9   unemployment_rate     4460 non-null   float64
#  10  num_committed_crimes  4460 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 386.8+ KB

# %% [markdown]
# #### Look at the rows with missing data in `account_district`

# %%
msk = account_district.isna().sum(axis=1)>0
account_district[msk]
# Out:
#       account_id  district_id                     frequency account_open_date  \
# 5           1972           77            MONTHLY STATEMENTS        1993-01-02
# 77          1000           77            MONTHLY STATEMENTS        1993-01-25
# 308          299           77            MONTHLY STATEMENTS        1993-04-05
# 322         8321           77            MONTHLY STATEMENTS        1993-04-12
# 394          551           77            MONTHLY STATEMENTS        1993-05-07
# 537         5228           77  STATEMENTS AFTER TRANSACTION        1993-06-23
# 574          368           77            MONTHLY STATEMENTS        1993-07-06
# 790         3157           77            MONTHLY STATEMENTS        1993-09-10
# 817          857           77            MONTHLY STATEMENTS        1993-09-16
# 832          153           77            MONTHLY STATEMENTS        1993-09-19
# 902         4119           77            MONTHLY STATEMENTS        1993-10-18
# 1161         742           77            MONTHLY STATEMENTS        1994-01-28
# 1331        1634           77            MONTHLY STATEMENTS        1994-06-04
# 1526        2377           77            MONTHLY STATEMENTS        1994-11-13
# 1622         217           77            MONTHLY STATEMENTS        1995-01-20
# 1716        3750           77            MONTHLY STATEMENTS        1995-03-18
# 1747        1590           77            MONTHLY STATEMENTS        1995-04-07
# 1806        2919           77            MONTHLY STATEMENTS        1995-05-10
# 1847          53           77            MONTHLY STATEMENTS        1995-06-07
# 2134        2157           77            MONTHLY STATEMENTS        1995-11-08
# 2336         976           77            MONTHLY STATEMENTS        1996-01-27
# 2392        1737           77            MONTHLY STATEMENTS        1996-02-13
# 2422         184           77            MONTHLY STATEMENTS        1996-02-21
# 2438        1962           77            MONTHLY STATEMENTS        1996-02-24
# 2451        1216           77            MONTHLY STATEMENTS        1996-03-01
# 2684        2994           77            MONTHLY STATEMENTS        1996-05-03
# 2709        3248           77            MONTHLY STATEMENTS        1996-05-11
# 2829        3647           77            MONTHLY STATEMENTS        1996-06-17
# 2881        7181           77  STATEMENTS AFTER TRANSACTION        1996-07-02
# 3002        4389           77            MONTHLY STATEMENTS        1996-07-28
# 3232        2332           77            MONTHLY STATEMENTS        1996-09-24
# 3372        1683           77            MONTHLY STATEMENTS        1996-11-01
# 3514        5817           77  STATEMENTS AFTER TRANSACTION        1996-12-10
# 3520        4631           77  STATEMENTS AFTER TRANSACTION        1996-12-12
# 3677        3990           77            MONTHLY STATEMENTS        1997-02-04
# 3723        4268           77            MONTHLY STATEMENTS        1997-02-20
# 3969        3172           77            MONTHLY STATEMENTS        1997-05-27
# 4050        2883           77            MONTHLY STATEMENTS        1997-06-29
# 4092        3833           77            MONTHLY STATEMENTS        1997-07-13
# 4137        3686           77            MONTHLY STATEMENTS        1997-08-03
#
#       client_id district_name region  population  average_salary  \
# 5          2397           NaN    NaN         NaN             NaN
# 77         1204           NaN    NaN         NaN             NaN
# 308         364           NaN    NaN         NaN             NaN
# 322       10275           NaN    NaN         NaN             NaN
# 394         664           NaN    NaN         NaN             NaN
# 537        6317           NaN    NaN         NaN             NaN
# 574         448           NaN    NaN         NaN             NaN
# 790        3817           NaN    NaN         NaN             NaN
# 817        1032           NaN    NaN         NaN             NaN
# 832         185           NaN    NaN         NaN             NaN
# 902        4959           NaN    NaN         NaN             NaN
# 1161        890           NaN    NaN         NaN             NaN
# 1331       1980           NaN    NaN         NaN             NaN
# 1526       2872           NaN    NaN         NaN             NaN
# 1622        262           NaN    NaN         NaN             NaN
# 1716       4524           NaN    NaN         NaN             NaN
# 1747       1927           NaN    NaN         NaN             NaN
# 1806       3527           NaN    NaN         NaN             NaN
# 1847         62           NaN    NaN         NaN             NaN
# 2134       2611           NaN    NaN         NaN             NaN
# 2336       1177           NaN    NaN         NaN             NaN
# 2392       2108           NaN    NaN         NaN             NaN
# 2422        224           NaN    NaN         NaN             NaN
# 2438       2387           NaN    NaN         NaN             NaN
# 2451       1468           NaN    NaN         NaN             NaN
# 2684       3616           NaN    NaN         NaN             NaN
# 2709       3928           NaN    NaN         NaN             NaN
# 2829       4398           NaN    NaN         NaN             NaN
# 2881       8667           NaN    NaN         NaN             NaN
# 3002       5287           NaN    NaN         NaN             NaN
# 3232       2820           NaN    NaN         NaN             NaN
# 3372       2043           NaN    NaN         NaN             NaN
# 3514       7043           NaN    NaN         NaN             NaN
# 3520       5579           NaN    NaN         NaN             NaN
# 3677       4811           NaN    NaN         NaN             NaN
# 3723       5143           NaN    NaN         NaN             NaN
# 3969       3836           NaN    NaN         NaN             NaN
# 4050       3485           NaN    NaN         NaN             NaN
# 4092       4619           NaN    NaN         NaN             NaN
# 4137       4444           NaN    NaN         NaN             NaN
#
#       unemployment_rate  num_committed_crimes
# 5                   NaN                   NaN
# 77                  NaN                   NaN
# 308                 NaN                   NaN
# 322                 NaN                   NaN
# 394                 NaN                   NaN
# 537                 NaN                   NaN
# 574                 NaN                   NaN
# 790                 NaN                   NaN
# 817                 NaN                   NaN
# 832                 NaN                   NaN
# 902                 NaN                   NaN
# 1161                NaN                   NaN
# 1331                NaN                   NaN
# 1526                NaN                   NaN
# 1622                NaN                   NaN
# 1716                NaN                   NaN
# 1747                NaN                   NaN
# 1806                NaN                   NaN
# 1847                NaN                   NaN
# 2134                NaN                   NaN
# 2336                NaN                   NaN
# 2392                NaN                   NaN
# 2422                NaN                   NaN
# 2438                NaN                   NaN
# 2451                NaN                   NaN
# 2684                NaN                   NaN
# 2709                NaN                   NaN
# 2829                NaN                   NaN
# 2881                NaN                   NaN
# 3002                NaN                   NaN
# 3232                NaN                   NaN
# 3372                NaN                   NaN
# 3514                NaN                   NaN
# 3520                NaN                   NaN
# 3677                NaN                   NaN
# 3723                NaN                   NaN
# 3969                NaN                   NaN
# 4050                NaN                   NaN
# 4092                NaN                   NaN
# 4137                NaN                   NaN

# %% [markdown]
# #### Use `SimpleImputer` from `sklearn` to impute the missing data in columns `population`, `average_salary`, `unemployment_rate`, `num_committed_crimes` with their means

# %%
from sklearn.impute import SimpleImputer as si
imp_mean=si(strategy='mean')

# %% [markdown]
# #### Use `fillna` method to impute the missing data in columns `district_name` and `region` with 'UNKNOWN'

# %%
district['district_name']=district['district_name'].fillna('UNKNOWN')
district['region']=district['region'].fillna('UNKNOWN')

# %% [markdown]
# ### 15. Merge (left join) `trans` and `account_district` into a new DataFrame called `all_data` using their common columns

# %%
all_data=pd.merge(trans,account_district,on='account_id',how='left')

# %% [markdown]
# #### Check the information summary of `all_data`

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 20 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   trans_id              1056320 non-null  int64
#  1   account_id            1056320 non-null  int64
#  2   date                  1056320 non-null  datetime64[ns]
#  3   type                  1056320 non-null  object
#  4   operation_type        1056320 non-null  object
#  5   amount                1056320 non-null  float64
#  6   balance               1056320 non-null  float64
#  7   description           1056320 non-null  object
#  8   partner_bank          1056320 non-null  object
#  9   partner_account       1056320 non-null  float64
#  10  district_id           1056320 non-null  int64
#  11  frequency             1056320 non-null  object
#  12  account_open_date     1056320 non-null  datetime64[ns]
#  13  client_id             1056320 non-null  int64
#  14  district_name         1046264 non-null  object
#  15  region                1046264 non-null  object
#  16  population            1046264 non-null  float64
#  17  average_salary        1046264 non-null  float64
#  18  unemployment_rate     1046264 non-null  float64
#  19  num_committed_crimes  1046264 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(4), object(7)
# memory usage: 161.2+ MB

# %% [markdown]
# ### 16. Create a new column `account_open_year` and assign it as the year from column `account_open_date`

# %%
account['account_open_year']=account['account_open_date'].dt.year

# %% [markdown]
# ### 17. Calculate the difference between columns `date` (transaction date) and `account_open_date`

# %%
diff=all_data['date']-all_data['account_open_date']
diff
# Out:
# 0            0 days
# 1            0 days
# 2            0 days
# 3            0 days
# 4            0 days
#              ...
# 1056315    832 days
# 1056316   1326 days
# 1056317    825 days
# 1056318   1939 days
# 1056319   2163 days
# Length: 1056320, dtype: timedelta64[ns]

# %% [markdown]
# ### 18. Create a new column `account_age_days` and assign it as the difference in days between columns `date` (transaction date) and `account_open_date`

# %%
all_data['account_age_days']=trans['date']-account['account_open_date']
all_data['account_age_days']
# Out:
# 0         0 days
# 1         0 days
# 2         0 days
# 3         0 days
# 4         0 days
#            ...
# 1056315      NaT
# 1056316      NaT
# 1056317      NaT
# 1056318      NaT
# 1056319      NaT
# Name: account_age_days, Length: 1056320, dtype: timedelta64[ns]

# %% [markdown]
# ### 19. Create a new column `amount_category` by cutting the column `amount` into 3 equal-sized bins, and label the bins as 'low_amount', 'medium_amount', 'high_amount'

# %%
amount_category=pd.cut(all_data['amount'],3,labels=['low_amount','medium_amount','high_amount'])
amount_category
# Out:
# 0          low_amount
# 1          low_amount
# 2          low_amount
# 3          low_amount
# 4          low_amount
#               ...
# 1056315    low_amount
# 1056316    low_amount
# 1056317    low_amount
# 1056318    low_amount
# 1056319    low_amount
# Name: amount, Length: 1056320, dtype: category
# Categories (3, object): ['low_amount' < 'medium_amount' < 'high_amount']

# %% [markdown]
# #### Verify the categories and their counts in `amount_category`

# %%
amount_category.value_counts()
# Out:
# amount
# low_amount       1013033
# medium_amount      41336
# high_amount         1951
# Name: count, dtype: int64

# %% [markdown]
# ### 20. Create a new column `account_age_days_category` by cutting the column `account_age_days` into 5 equal-width bins

# %%
account_age_days_category=pd.cut(all_data['account_age_days'],5)
account_age_days_category
# Out:
# 0          (-331 days +09:36:00, 0 days 00:00:00]
# 1          (-331 days +09:36:00, 0 days 00:00:00]
# 2          (-331 days +09:36:00, 0 days 00:00:00]
# 3          (-331 days +09:36:00, 0 days 00:00:00]
# 4          (-331 days +09:36:00, 0 days 00:00:00]
#                             ...
# 1056315                                       NaN
# 1056316                                       NaN
# 1056317                                       NaN
# 1056318                                       NaN
# 1056319                                       NaN
# Name: account_age_days, Length: 1056320, dtype: category
# Categories (5, interval[timedelta64[ns], right]): [ <
#                                                    (-1655 days +08:19:40.800000, -1323 days +14:2... <
#                                                    (-1323 days +14:24:00, -992 days +04:48:00] <
#                                                    (-992 days +04:48:00, -662 days +19:12:00] <
#                                                    (-662 days +19:12:00, -331 days +09:36:00] <
#                                                    (-331 days +09:36:00, 0 days 00:00:00]]

# %% [markdown]
# #### Verify the categories and their counts in `account_age_days_category`

# %%
account_age_days_category.value_counts()
# Out:
# account_age_days
# (-1323 days +14:24:00, -992 days +04:48:00]            1322
# (-331 days +09:36:00, 0 days 00:00:00]                 1188
# (-1655 days +08:19:40.800000, -1323 days +14:24:00]     858
# (-992 days +04:48:00, -662 days +19:12:00]              673
# (-662 days +19:12:00, -331 days +09:36:00]              459
# Name: count, dtype: int64

# %% [markdown]
# #### Print out the first 20 rows of `all_data` to look at the newly added columns

# %%
all_data.head(50)
# Out:
#     trans_id  account_id       date    type                operation_type  \
# 0     695247        2378 1993-01-01  CREDIT                CREDIT IN CASH
# 1     171812         576 1993-01-01  CREDIT                CREDIT IN CASH
# 2     207264         704 1993-01-01  CREDIT                CREDIT IN CASH
# 3    1117247        3818 1993-01-01  CREDIT                CREDIT IN CASH
# 4     579373        1972 1993-01-02  CREDIT                CREDIT IN CASH
# 5     771035        2632 1993-01-02  CREDIT                CREDIT IN CASH
# 6     452728        1539 1993-01-03  CREDIT                CREDIT IN CASH
# 7     725751        2484 1993-01-03  CREDIT                CREDIT IN CASH
# 8     497211        1695 1993-01-03  CREDIT                CREDIT IN CASH
# 9     232960         793 1993-01-03  CREDIT                CREDIT IN CASH
# 10    505240        1726 1993-01-03  CREDIT                CREDIT IN CASH
# 11    144541         485 1993-01-04  CREDIT                CREDIT IN CASH
# 12    637741        2177 1993-01-04  CREDIT                CREDIT IN CASH
# 13    689827        2357 1993-01-04  CREDIT                CREDIT IN CASH
# 14    846006        2881 1993-01-04  CREDIT                CREDIT IN CASH
# 15    637742        2177 1993-01-05  CREDIT  COLLECTION FROM ANOTHER BANK
# 16   2908688        9635 1993-01-05  CREDIT                CREDIT IN CASH
# 17    232961         793 1993-01-05  CREDIT  COLLECTION FROM ANOTHER BANK
# 18    192096         652 1993-01-05  CREDIT                CREDIT IN CASH
# 19    542215        1844 1993-01-06  CREDIT                CREDIT IN CASH
# 20    565654        1926 1993-01-06  CREDIT                CREDIT IN CASH
# 21    542216        1844 1993-01-07  CREDIT  COLLECTION FROM ANOTHER BANK
# 22   1027725        3510 1993-01-07  CREDIT                CREDIT IN CASH
# 23    374589        1276 1993-01-07  CREDIT                CREDIT IN CASH
# 24    579374        1972 1993-01-07  CREDIT  COLLECTION FROM ANOTHER BANK
# 25    699220        2393 1993-01-07  CREDIT                CREDIT IN CASH
# 26    129502         435 1993-01-08  CREDIT                CREDIT IN CASH
# 27    374590        1276 1993-01-08  CREDIT                CREDIT IN CASH
# 28     57433         192 1993-01-08  CREDIT                CREDIT IN CASH
# 29    497212        1695 1993-01-08  CREDIT                CREDIT IN CASH
# 30    621760        2122 1993-01-08  CREDIT                CREDIT IN CASH
# 31    480214        1637 1993-01-08  CREDIT                CREDIT IN CASH
# 32    612392        2087 1993-01-08  CREDIT                CREDIT IN CASH
# 33    224342         764 1993-01-08  CREDIT                CREDIT IN CASH
# 34   1049881        3592 1993-01-08  CREDIT                CREDIT IN CASH
# 35   1132662        3871 1993-01-08  CREDIT                CREDIT IN CASH
# 36   1021120        3487 1993-01-08  CREDIT                CREDIT IN CASH
# 37    439035        1493 1993-01-09  CREDIT                CREDIT IN CASH
# 38    110534         374 1993-01-09  CREDIT                CREDIT IN CASH
# 39    771036        2632 1993-01-09  CREDIT                CREDIT IN CASH
# 40    506450        1730 1993-01-09  CREDIT                CREDIT IN CASH
# 41    192097         652 1993-01-09  CREDIT                CREDIT IN CASH
# 42   1117248        3818 1993-01-09  CREDIT                CREDIT IN CASH
# 43    695720        2379 1993-01-10  CREDIT                CREDIT IN CASH
# 44    857973        2925 1993-01-10  CREDIT                CREDIT IN CASH
# 45    477638        1628 1993-01-10  CREDIT                CREDIT IN CASH
# 46   1049882        3592 1993-01-10  CREDIT  COLLECTION FROM ANOTHER BANK
# 47    252644         866 1993-01-10  CREDIT                CREDIT IN CASH
# 48    393505        1338 1993-01-11  CREDIT                CREDIT IN CASH
# 49    171813         576 1993-01-11  CREDIT  COLLECTION FROM ANOTHER BANK
#
#      amount  balance description partner_bank  partner_account  ...  \
# 0     700.0    700.0     unknown      unknown           -999.0  ...
# 1     900.0    900.0     unknown      unknown           -999.0  ...
# 2    1000.0   1000.0     unknown      unknown           -999.0  ...
# 3     600.0    600.0     unknown      unknown           -999.0  ...
# 4     400.0    400.0     unknown      unknown           -999.0  ...
# 5    1100.0   1100.0     unknown      unknown           -999.0  ...
# 6     600.0    600.0     unknown      unknown           -999.0  ...
# 7    1100.0   1100.0     unknown      unknown           -999.0  ...
# 8     200.0    200.0     unknown      unknown           -999.0  ...
# 9     800.0    800.0     unknown      unknown           -999.0  ...
# 10   1000.0   1000.0     unknown      unknown           -999.0  ...
# 11    300.0    300.0     unknown      unknown           -999.0  ...
# 12    800.0    800.0     unknown      unknown           -999.0  ...
# 13    800.0    800.0     unknown      unknown           -999.0  ...
# 14    700.0    700.0     unknown      unknown           -999.0  ...
# 15   5123.0   5923.0     PENSION           YZ       62457513.0  ...
# 16    400.0    400.0     unknown      unknown           -999.0  ...
# 17   3401.0   4201.0     unknown           IJ        6149286.0  ...
# 18    700.0    700.0     unknown      unknown           -999.0  ...
# 19    500.0    500.0     unknown      unknown           -999.0  ...
# 20    700.0    700.0     unknown      unknown           -999.0  ...
# 21   3242.0   3742.0     unknown           ST       42988401.0  ...
# 22    500.0    500.0     unknown      unknown           -999.0  ...
# 23    400.0    400.0     unknown      unknown           -999.0  ...
# 24   5298.0   5698.0     PENSION           UV       14132887.0  ...
# 25    900.0    900.0     unknown      unknown           -999.0  ...
# 26    400.0    400.0     unknown      unknown           -999.0  ...
# 27   6774.0   7174.0     unknown      unknown           -999.0  ...
# 28    300.0    300.0     unknown      unknown           -999.0  ...
# 29  11832.0  12032.0     unknown      unknown           -999.0  ...
# 30    300.0    300.0     unknown      unknown           -999.0  ...
# 31    500.0    500.0     unknown      unknown           -999.0  ...
# 32    600.0    600.0     unknown      unknown           -999.0  ...
# 33   1100.0   1100.0     unknown      unknown           -999.0  ...
# 34    600.0    600.0     unknown      unknown           -999.0  ...
# 35    300.0    300.0     unknown      unknown           -999.0  ...
# 36    800.0    800.0     unknown      unknown           -999.0  ...
# 37    200.0    200.0     unknown      unknown           -999.0  ...
# 38    400.0    400.0     unknown      unknown           -999.0  ...
# 39  14264.0  15364.0     unknown      unknown           -999.0  ...
# 40    900.0    900.0     unknown      unknown           -999.0  ...
# 41  13851.0  14551.0     unknown      unknown           -999.0  ...
# 42  17366.0  17966.0     unknown      unknown           -999.0  ...
# 43    800.0    800.0     unknown      unknown           -999.0  ...
# 44   1000.0   1000.0     unknown      unknown           -999.0  ...
# 45    700.0    700.0     unknown      unknown           -999.0  ...
# 46   6007.0   6607.0     PENSION           MN       73166322.0  ...
# 47    500.0    500.0     unknown      unknown           -999.0  ...
# 48    400.0    400.0     unknown      unknown           -999.0  ...
# 49   6207.0   7107.0     PENSION           YZ       30300313.0  ...
#
#                        frequency account_open_date client_id  \
# 0             MONTHLY STATEMENTS        1993-01-01      2873
# 1             MONTHLY STATEMENTS        1993-01-01       692
# 2             MONTHLY STATEMENTS        1993-01-01       844
# 3             MONTHLY STATEMENTS        1993-01-01      4601
# 4             MONTHLY STATEMENTS        1993-01-02      2397
# 5             MONTHLY STATEMENTS        1993-01-02      3177
# 6   STATEMENTS AFTER TRANSACTION        1993-01-03      1866
# 7             MONTHLY STATEMENTS        1993-01-03      2999
# 8             MONTHLY STATEMENTS        1993-01-03      2058
# 9             MONTHLY STATEMENTS        1993-01-03       950
# 10            MONTHLY STATEMENTS        1993-01-03      2093
# 11  STATEMENTS AFTER TRANSACTION        1993-01-04       583
# 12            MONTHLY STATEMENTS        1993-01-04      2636
# 13            MONTHLY STATEMENTS        1993-01-04      2849
# 14            MONTHLY STATEMENTS        1993-01-04      3483
# 15            MONTHLY STATEMENTS        1993-01-04      2636
# 16            MONTHLY STATEMENTS        1993-01-05     11860
# 17            MONTHLY STATEMENTS        1993-01-03       950
# 18            MONTHLY STATEMENTS        1993-01-05       782
# 19            MONTHLY STATEMENTS        1993-01-06      2236
# 20            MONTHLY STATEMENTS        1993-01-06      2338
# 21            MONTHLY STATEMENTS        1993-01-06      2236
# 22            MONTHLY STATEMENTS        1993-01-07      4238
# 23            MONTHLY STATEMENTS        1993-01-07      1540
# 24            MONTHLY STATEMENTS        1993-01-02      2397
# 25            MONTHLY STATEMENTS        1993-01-07      2889
# 26            MONTHLY STATEMENTS        1993-01-08       523
# 27            MONTHLY STATEMENTS        1993-01-07      1540
# 28            MONTHLY STATEMENTS        1993-01-08       232
# 29            MONTHLY STATEMENTS        1993-01-03      2058
# 30            MONTHLY STATEMENTS        1993-01-08      2566
# 31            MONTHLY STATEMENTS        1993-01-08      1984
# 32             WEEKLY STATEMENTS        1993-01-08      2530
# 33            MONTHLY STATEMENTS        1993-01-08       914
# 34            MONTHLY STATEMENTS        1993-01-08      4335
# 35            MONTHLY STATEMENTS        1993-01-08      4665
# 36            MONTHLY STATEMENTS        1993-01-08      4215
# 37            MONTHLY STATEMENTS        1993-01-09      1810
# 38            MONTHLY STATEMENTS        1993-01-09       454
# 39            MONTHLY STATEMENTS        1993-01-02      3177
# 40            MONTHLY STATEMENTS        1993-01-09      2099
# 41            MONTHLY STATEMENTS        1993-01-05       782
# 42            MONTHLY STATEMENTS        1993-01-01      4601
# 43            MONTHLY STATEMENTS        1993-01-10      2874
# 44            MONTHLY STATEMENTS        1993-01-10      3533
# 45            MONTHLY STATEMENTS        1993-01-10      1973
# 46            MONTHLY STATEMENTS        1993-01-08      4335
# 47            MONTHLY STATEMENTS        1993-01-10      1044
# 48            MONTHLY STATEMENTS        1993-01-11      1619
# 49            MONTHLY STATEMENTS        1993-01-01       692
#
#           district_name           region population  average_salary  \
# 0     JINDRICHUV HRADEC    SOUTH BOHEMIA    93931.0     8427.000000
# 1         BRNO - VENKOV    SOUTH MORAVIA   157042.0     9072.274638
# 2         BRNO - VENKOV    SOUTH MORAVIA   157042.0     9072.274638
# 3       OSTRAVA - MESTO    NORTH MORAVIA   323870.0    10673.000000
# 4                   NaN              NaN        NaN             NaN
# 5          KARLOVY VARY     WEST BOHEMIA   122603.0     8991.000000
# 6           HL.M. PRAHA           PRAGUE  1204953.0    12541.000000
# 7       OSTRAVA - MESTO    NORTH MORAVIA   323870.0    10673.000000
# 8               SUMPERK    NORTH MORAVIA   127369.0     8369.000000
# 9             PARDUBICE     EAST BOHEMIA   162580.0     9538.000000
# 10  RYCHNOV NAD KNEZNOU     EAST BOHEMIA    78955.0     9060.000000
# 11           KUTNA HORA  CENTRAL BOHEMIA    77963.0     8546.000000
# 12     UHERSKE HRADISTE    SOUTH MORAVIA   145688.0     8544.000000
# 13           PRACHATICE    SOUTH BOHEMIA    51428.0     8402.000000
# 14              KARVINA    NORTH MORAVIA   285387.0    10177.000000
# 15     UHERSKE HRADISTE    SOUTH MORAVIA   145688.0     8544.000000
# 16              KARVINA    NORTH MORAVIA   285387.0    10177.000000
# 17            PARDUBICE     EAST BOHEMIA   162580.0     9538.000000
# 18                TABOR    SOUTH BOHEMIA   103347.0     9104.000000
# 19              CHRUDIM     EAST BOHEMIA   105606.0     8254.000000
# 20           LITOMERICE    NORTH BOHEMIA   114006.0     9065.000000
# 21              CHRUDIM     EAST BOHEMIA   105606.0     8254.000000
# 22       USTI NAD LABEM    NORTH BOHEMIA   118650.0     9832.000000
# 23              LIBEREC    NORTH BOHEMIA   159617.0     9198.000000
# 24                  NaN              NaN        NaN             NaN
# 25       PRAHA - VYCHOD  CENTRAL BOHEMIA    92084.0    10124.000000
# 26                LOUNY    NORTH BOHEMIA    85852.0     8965.000000
# 27              LIBEREC    NORTH BOHEMIA   159617.0     9198.000000
# 28        BRNO - VENKOV    SOUTH MORAVIA   157042.0     9072.274638
# 29              SUMPERK    NORTH MORAVIA   127369.0     8369.000000
# 30      FRYDEK - MISTEK    NORTH MORAVIA   228848.0     9893.000000
# 31          HL.M. PRAHA           PRAGUE  1204953.0    12541.000000
# 32               MELNIK  CENTRAL BOHEMIA    94725.0     8836.006723
# 33          HL.M. PRAHA           PRAGUE  1204953.0    12541.000000
# 34         BRNO - MESTO    SOUTH MORAVIA   387570.0     9945.418311
# 35        PLZEN - MESTO     WEST BOHEMIA   170449.0    10787.000000
# 36       USTI NAD LABEM    NORTH BOHEMIA   118650.0     9832.000000
# 37       USTI NAD LABEM    NORTH BOHEMIA   118650.0     9832.000000
# 38                LOUNY    NORTH BOHEMIA    85852.0     8965.000000
# 39         KARLOVY VARY     WEST BOHEMIA   122603.0     8991.000000
# 40          HL.M. PRAHA           PRAGUE  1204953.0    12541.000000
# 41                TABOR    SOUTH BOHEMIA   103347.0     9104.000000
# 42      OSTRAVA - MESTO    NORTH MORAVIA   323870.0    10673.000000
# 43              CHRUDIM     EAST BOHEMIA   105606.0     8254.000000
# 44          HL.M. PRAHA           PRAGUE  1204953.0    12541.000000
# 45            PROSTEJOV    SOUTH MORAVIA   110643.0     8441.000000
# 46         BRNO - MESTO    SOUTH MORAVIA   387570.0     9945.418311
# 47              NYMBURK  CENTRAL BOHEMIA    81344.0     8899.000000
# 48      OSTRAVA - MESTO    NORTH MORAVIA   323870.0    10673.000000
# 49        BRNO - VENKOV    SOUTH MORAVIA   157042.0     9072.274638
#
#     unemployment_rate  num_committed_crimes  account_age_days
# 0            1.540000           1913.000000            0 days
# 1            2.430000           3894.000000            0 days
# 2            2.430000           3894.000000            0 days
# 3            5.440000          18347.000000            0 days
# 4                 NaN                   NaN            0 days
# 5            2.010000           5273.000000            0 days
# 6            0.430000          99107.000000            0 days
# 7            5.440000          18347.000000            0 days
# 8            3.818541           2807.000000            0 days
# 9            4.315642           5410.000000            0 days
# 10           2.440000           1717.000000            0 days
# 11           4.020000           3120.000000            0 days
# 12           1.860000           2906.000000            0 days
# 13           3.980000           1099.000000            0 days
# 14           7.750000          10108.000000            0 days
# 15           1.860000           2906.000000            0 days
# 16           7.750000          10108.000000            0 days
# 17           4.315642           5410.000000           -1 days
# 18           2.070000           2354.000000           -1 days
# 19           3.760000           2325.000000           -1 days
# 20           5.390000           4166.000000           -1 days
# 21           3.760000           2325.000000            0 days
# 22           4.480000           3782.711106           -1 days
# 23           4.280000           6132.000000           -1 days
# 24                NaN                   NaN           -1 days
# 25           0.540000           1630.642957           -1 days
# 26           3.795809           2822.000000            0 days
# 27           4.280000           6132.000000            0 days
# 28           2.430000           3894.000000            0 days
# 29           3.818541           2807.000000            0 days
# 30           4.720000          12703.935555            0 days
# 31           0.430000          99107.000000           -1 days
# 32           2.870000           4846.000000           -1 days
# 33           0.430000          99107.000000           -1 days
# 34           1.960000          18696.000000           -2 days
# 35           4.885392           6261.000000           -2 days
# 36           4.480000           3782.711106           -2 days
# 37           4.480000           3782.711106           -1 days
# 38           3.795809           2822.000000           -2 days
# 39           2.010000           5273.000000           -2 days
# 40           0.430000          99107.000000           -2 days
# 41           2.070000           2354.000000           -3 days
# 42           5.440000          18347.000000           -3 days
# 43           3.760000           2325.000000           -3 days
# 44           0.430000          99107.000000           -3 days
# 45           4.480000           2252.000000           -4 days
# 46           1.960000          18696.000000           -4 days
# 47           3.970000           2487.000000           -4 days
# 48           5.440000          18347.000000           -3 days
# 49           2.430000           3894.000000           -3 days
#
# [50 rows x 21 columns]
